# %% [markdown]
# ### Import library

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pip>=24.3.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 1)) (24.3.1)
# Requirement already satisfied: notebook>=5.5.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 2)) (7.2.2)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: seaborn>=0.8.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: matplotlib>=2.2.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: tqdm>=4.64.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: plotly>=5.13.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from -r requirements.txt (line 8)) (5.24.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (4.2.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (6.4.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (2024.8.30)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (6.4.5)
# Requirement already satisfied: colorama in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from tqdm>=4.64.1->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from plotly>=5.13.0->-r requirements.txt (line 8)) (9.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=2.2.2->-r requirements.txt (line 6)) (3.21.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (4.6.2.post1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.0.14)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.27.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (68.2.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: babel>=2.10 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23.0->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.8.9)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=5.5.0->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (308)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: tinycss2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.21.0)
# Requirement already satisfied: webencodings in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: decorator in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (3.0.48)
# Requirement already satisfied: stack-data in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: fqdn in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.6)
# Requirement already satisfied: pycparser in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\user\pycharmprojects\jupyterproject\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5.5.0->-r requirements.txt (line 2)) (2.9.0.20241003)

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px

# %% [markdown]
# ### Start session
# Enter credentials once - they will be saved to local folder and loaded each time

# %%
s = ace.start_session()

# %% [markdown]
# ### Create list of alpha expressions
# #### Step 1. Download datsets

# %%
datasets_df = hf.get_datasets(s) # by default we load all datasets USA TOP3000 delay 1
datasets_df.head(120) # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#             id                                name  \
# 0    analyst11                          ESG scores
# 1    analyst12      Social Media Relation Dataset
# 2    analyst14     Estimations of Key Fundamentals
# 3    analyst15                  Earnings forecasts
# 4    analyst16                 Real Time Estimates
# ..         ...                                 ...
# 115   model176         Non-Financial Metric Models
# 116   model182      Geographic network based model
# 117   model194      North America CDS Factor Model
# 118    model20  Fundamental & Technical Rank Model
# 119    model21             Equity Focus Rank Model
#
#                                            description  \
# 0    Environmental Social Governance scores that ex...
# 1                       Social media relation dataset
# 2    This dataset reports many items from financial...
# 3    This dataset provides bottom-up forecast data ...
# 4    This dataset provides real-time access to the ...
# ..                                                 ...
# 115  Ratings that quantify non-financial statement ...
# 116  Price momentum scores based on different model...
# 117  Financial derivative that transfers credit ris...
# 118  This dataset weighs fundamental and technical ...
# 119  This is a model data using composite factor of...
#
#                                  category  \
# 0    {'id': 'analyst', 'name': 'Analyst'}
# 1    {'id': 'analyst', 'name': 'Analyst'}
# 2    {'id': 'analyst', 'name': 'Analyst'}
# 3    {'id': 'analyst', 'name': 'Analyst'}
# 4    {'id': 'analyst', 'name': 'Analyst'}
# ..                                    ...
# 115      {'id': 'model', 'name': 'Model'}
# 116      {'id': 'model', 'name': 'Model'}
# 117      {'id': 'model', 'name': 'Model'}
# 118      {'id': 'model', 'name': 'Model'}
# 119      {'id': 'model', 'name': 'Model'}
#
#                                            subcategory region  delay universe  \
# 0                 {'id': 'analyst-esg', 'name': 'ESG'}    USA      1  TOP3000
# 1    {'id': 'analyst-crowdsourced-estimates', 'name...    USA      1  TOP3000
# 2    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 3    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 4    {'id': 'analyst-crowdsourced-estimates', 'name...    USA      1  TOP3000
# ..                                                 ...    ...    ...      ...
# 115  {'id': 'model-consumer-models', 'name': 'Consu...    USA      1  TOP3000
# 116  {'id': 'model-momentum-models', 'name': 'Momen...    USA      1  TOP3000
# 117  {'id': 'model-risk-models', 'name': 'Risk Mode...    USA      1  TOP3000
# 118  {'id': 'model-technical-models', 'name': 'Tech...    USA      1  TOP3000
# 119  {'id': 'model-technical-models', 'name': 'Tech...    USA      1  TOP3000
#
#      coverage  valueScore  userCount  alphaCount  fieldCount  \
# 0      0.6818         2.0        267        3444         197
# 1      0.6178         5.0         14          23          12
# 2      0.6203         2.0        590       37643         868
# 3      0.9892         2.0        681       69878        2538
# 4      0.8252         2.0        165        2633         107
# ..        ...         ...        ...         ...         ...
# 115    0.4978         3.0         73         375          23
# 116    0.5777         3.0         35         147           8
# 117    1.0000         2.0        126        1707         105
# 118    0.4582         2.0         25         169           1
# 119    0.4608         3.0          8          24           1
#
#      pyramidMultiplier themes  \
# 0                  1.1     []
# 1                  1.1     []
# 2                  1.1     []
# 3                  1.1     []
# 4                  1.1     []
# ..                 ...    ...
# 115                1.2     []
# 116                1.2     []
# 117                1.2     []
# 118                1.2     []
# 119                1.2     []
#
#                                         researchPapers
# 0    [{'title': 'Research Paper 19: ESG Preference,...
# 1                                                   []
# 2    [{'title': 'Research Paper 10: Investor Learni...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 115                                                 []
# 116                                                 []
# 117                                                 []
# 118                                                 []
# 119                                                 []
#
# [120 rows x 16 columns]

# %%
# select needed datasets
selected_datasets_df = datasets_df[
    (datasets_df["delay"] == 1) &
    (datasets_df["coverage"] > 0.8) & (datasets_df["coverage"] <= 1) &
    (datasets_df["fieldCount"] > 0) & (datasets_df["fieldCount"] < 1000) &
    (datasets_df["region"] == 'USA') &
    (datasets_df["universe"] == 'TOP3000') &
    (datasets_df["userCount"] > 0) & (datasets_df["userCount"] < 100) &
    (datasets_df["valueScore"] > 1) & (datasets_df["valueScore"] < 100) #&
   #datasets_df["name"].str.contains('news', case=False) &
    #((datasets_df["category"] == 'news'))|((datasets_df["category"] == 'analyst'))
].sort_values(by=['valueScore'], ascending=False)
selected_datasets_df
# Out:
#                id                                               name  \
# 129      model238                                SmartHoldings Model
# 276      other631                         Option Trade Activity Data
# 282      other733       Classification based on Business description
# 32     earnings14                             Upcoming Earnings Data
# 89        macro52                                   ETF Constituents
# ..            ...                                                ...
# 239      other193  Systematic Hedging for Investors to Evade Larg...
# 308        risk60                    Securities Lending Insight Data
# 290         pv104                         Market Microstructure Data
# 338  socialmedia3                       Twitter based sentiment data
# 343  socialmedia9                         Social Media Activity Data
#
#                                            description  \
# 129  This dataset is a global stock selection model...
# 276  The dataset provides End-of-Day and Intra-Day ...
# 282  Classifying stocks on the basis of the their a...
# 32   This particular dataset deals with earnings re...
# 89   Historical and Daily Holdings information of ETFs
# ..                                                 ...
# 239  Machine learning based stock selection model. ...
# 308  The dataset provides list of metrics, covering...
# 290  The dataset is perfect to add extra flavor to ...
# 338  Sentiment scores derived from social media. So...
# 343  The dataset captures short-term estimated sent...
#
#                                           category  \
# 129               {'id': 'model', 'name': 'Model'}
# 276               {'id': 'other', 'name': 'Other'}
# 282               {'id': 'other', 'name': 'Other'}
# 32          {'id': 'earnings', 'name': 'Earnings'}
# 89                {'id': 'macro', 'name': 'Macro'}
# ..                                             ...
# 239               {'id': 'model', 'name': 'Model'}
# 308                 {'id': 'risk', 'name': 'Risk'}
# 290           {'id': 'pv', 'name': 'Price Volume'}
# 338  {'id': 'socialmedia', 'name': 'Social Media'}
# 343  {'id': 'socialmedia', 'name': 'Social Media'}
#
#                                            subcategory region  delay universe  \
# 129  {'id': 'model-estimates-models', 'name': 'Esti...    USA      1  TOP3000
# 276   {'id': 'other-etf-models', 'name': 'ETF Models'}    USA      1  TOP3000
# 282  {'id': 'other-analyst-models', 'name': 'Analys...    USA      1  TOP3000
# 32   {'id': 'earnings-earnings-estimates', 'name': ...    USA      1  TOP3000
# 89   {'id': 'macro-macroeconomic-activities', 'name...    USA      1  TOP3000
# ..                                                 ...    ...    ...      ...
# 239  {'id': 'model-mlai-models', 'name': 'ML/AI Mod...    USA      1  TOP3000
# 308  {'id': 'risk-risk-models', 'name': 'Risk Models'}    USA      1  TOP3000
# 290  {'id': 'pv-price-volume', 'name': 'Price Volume'}    USA      1  TOP3000
# 338  {'id': 'socialmedia-social-media', 'name': 'So...    USA      1  TOP3000
# 343  {'id': 'socialmedia-social-media', 'name': 'So...    USA      1  TOP3000
#
#      coverage  valueScore  userCount  alphaCount  fieldCount  \
# 129    0.8198         7.0          1           1          11
# 276    0.8297         7.0         11          16         171
# 282    0.8542         7.0          1           3          10
# 32     0.8313         6.0          3           5           9
# 89     1.0000         6.0          3           5           3
# ..        ...         ...        ...         ...         ...
# 239    0.8845         2.0         98         520           3
# 308    0.9879         2.0         39         161           4
# 290    0.9633         2.0         74         482          45
# 338    0.9108         2.0         35          94           7
# 343    0.8787         2.0         22          60           4
#
#      pyramidMultiplier themes  \
# 129                1.2     []
# 276                1.3     []
# 282                1.3     []
# 32                 1.2     []
# 89                 1.0     []
# ..                 ...    ...
# 239                1.2     []
# 308                1.4     []
# 290                1.0     []
# 338                1.1     []
# 343                1.1     []
#
#                                         researchPapers
# 129                                                 []
# 276                                                 []
# 282                                                 []
# 32                                                  []
# 89                                                  []
# ..                                                 ...
# 239                                                 []
# 308                                                 []
# 290                                                 []
# 338  [{'title': 'Research Paper 45: Online reviews ...
# 343                                                 []
#
# [80 rows x 16 columns]

# %% [markdown]
# For demonstration we are picking the dataset with the highest value score, this is not mandatory but definitely a recommended practice

# %% [markdown]
# #### Step 2. Select the needed datafields

# %%
dataset_id = selected_datasets_df.id.values.tolist()[58] # create a list of selected datasets ids, our list has only one element
dataset_id
# Out:
# 'news38'

# %%
datafields_df = hf.get_datafields(s, dataset_id=dataset_id) # download all fields of dataset news
datafields_df.head(25000)
# Out:
#                                     id  \
# 0                         mws38_action
# 1                    mws38_entitlement
# 2      mws38_headlinetones_entitlement
# 3   mws38_headlinetones_sg_entitlement
# 4          mws38_headlinetones_sg_time
# 5   mws38_headlinetones_tc_entitlement
# 6          mws38_headlinetones_tc_time
# 7             mws38_headlinetones_time
# 8                  mws38_negative_freq
# 9                 mws38_negative_score
# 10                 mws38_positive_freq
# 11                mws38_positive_score
# 12                   mws38_related_num
# 13                    mws38_relevances
# 14              mws38_sg_negative_freq
# 15             mws38_sg_negative_score
# 16              mws38_sg_positive_freq
# 17             mws38_sg_positive_score
# 18                 mws38_sg_tone_score
# 19    mws38_storyanalytics_entitlement
# 20          mws38_storyanalytics_score
# 21           mws38_storyanalytics_time
# 22           mws38_storyanalytics_type
# 23          mws38_storyanalytics_value
# 24              mws38_tc_negative_freq
# 25             mws38_tc_negative_score
# 26              mws38_tc_positive_freq
# 27             mws38_tc_positive_score
# 28                 mws38_tc_tone_score
# 29                          mws38_time
# 30                    mws38_tone_score
# 31                   mws38_uniq_action
# 32              mws38_uniq_entitlement
# 33              mws38_uniq_long_action
# 34         mws38_uniq_long_entitlement
# 35         mws38_uniq_long_related_num
# 36          mws38_uniq_long_relevances
# 37                mws38_uniq_long_time
# 38             mws38_uniq_long_version
# 39               mws38_uniq_new_action
# 40          mws38_uniq_new_entitlement
# 41          mws38_uniq_new_related_num
# 42           mws38_uniq_new_relevances
# 43                 mws38_uniq_new_time
# 44              mws38_uniq_new_version
# 45              mws38_uniq_related_num
# 46               mws38_uniq_relevances
# 47                     mws38_uniq_time
# 48                  mws38_uniq_version
# 49                       mws38_version
#
#                                           description  \
# 0                                         News action
# 1                           News entitlement ID (EID)
# 2                           News entitlement ID (EID)
# 3                           News entitlement ID (EID)
# 4                                           News time
# 5                           News entitlement ID (EID)
# 6                                           News time
# 7                                           News time
# 8                                  Negative frequency
# 9                                      Negative score
# 10                                 Positive frequency
# 11                                     Positive score
# 12  Number of stocks related to or affected by the...
# 13  Degree of relevance the news is to the corresp...
# 14                                 Negative frequency
# 15                                     Negative score
# 16                                 Positive frequency
# 17                                     Positive score
# 18                                         Tone score
# 19                          News entitlement ID (EID)
# 20                                         News score
# 21                                          News time
# 22                                          News type
# 23                                         News value
# 24                                 Negative frequency
# 25                                     Negative score
# 26                                 Positive frequency
# 27                                     Positive score
# 28                                         Tone score
# 29                                          News time
# 30                                         Tone score
# 31                                        News action
# 32                          News entitlement ID (EID)
# 33                                        News action
# 34                          News entitlement ID (EID)
# 35  Number of stocks related to or affected by the...
# 36  Degree of relevance the news is to the corresp...
# 37                                          News time
# 38                                       News version
# 39                                        News action
# 40                          News entitlement ID (EID)
# 41  Number of stocks related to or affected by the...
# 42  Degree of relevance the news is to the corresp...
# 43                                          News time
# 44                                       News version
# 45  Number of stocks related to or affected by the...
# 46  Degree of relevance the news is to the corresp...
# 47                                          News time
# 48                                       News version
# 49                                       News version
#
#                                               dataset  \
# 0   {'id': 'news38', 'name': 'News Analytic Model ...
# 1   {'id': 'news38', 'name': 'News Analytic Model ...
# 2   {'id': 'news38', 'name': 'News Analytic Model ...
# 3   {'id': 'news38', 'name': 'News Analytic Model ...
# 4   {'id': 'news38', 'name': 'News Analytic Model ...
# 5   {'id': 'news38', 'name': 'News Analytic Model ...
# 6   {'id': 'news38', 'name': 'News Analytic Model ...
# 7   {'id': 'news38', 'name': 'News Analytic Model ...
# 8   {'id': 'news38', 'name': 'News Analytic Model ...
# 9   {'id': 'news38', 'name': 'News Analytic Model ...
# 10  {'id': 'news38', 'name': 'News Analytic Model ...
# 11  {'id': 'news38', 'name': 'News Analytic Model ...
# 12  {'id': 'news38', 'name': 'News Analytic Model ...
# 13  {'id': 'news38', 'name': 'News Analytic Model ...
# 14  {'id': 'news38', 'name': 'News Analytic Model ...
# 15  {'id': 'news38', 'name': 'News Analytic Model ...
# 16  {'id': 'news38', 'name': 'News Analytic Model ...
# 17  {'id': 'news38', 'name': 'News Analytic Model ...
# 18  {'id': 'news38', 'name': 'News Analytic Model ...
# 19  {'id': 'news38', 'name': 'News Analytic Model ...
# 20  {'id': 'news38', 'name': 'News Analytic Model ...
# 21  {'id': 'news38', 'name': 'News Analytic Model ...
# 22  {'id': 'news38', 'name': 'News Analytic Model ...
# 23  {'id': 'news38', 'name': 'News Analytic Model ...
# 24  {'id': 'news38', 'name': 'News Analytic Model ...
# 25  {'id': 'news38', 'name': 'News Analytic Model ...
# 26  {'id': 'news38', 'name': 'News Analytic Model ...
# 27  {'id': 'news38', 'name': 'News Analytic Model ...
# 28  {'id': 'news38', 'name': 'News Analytic Model ...
# 29  {'id': 'news38', 'name': 'News Analytic Model ...
# 30  {'id': 'news38', 'name': 'News Analytic Model ...
# 31  {'id': 'news38', 'name': 'News Analytic Model ...
# 32  {'id': 'news38', 'name': 'News Analytic Model ...
# 33  {'id': 'news38', 'name': 'News Analytic Model ...
# 34  {'id': 'news38', 'name': 'News Analytic Model ...
# 35  {'id': 'news38', 'name': 'News Analytic Model ...
# 36  {'id': 'news38', 'name': 'News Analytic Model ...
# 37  {'id': 'news38', 'name': 'News Analytic Model ...
# 38  {'id': 'news38', 'name': 'News Analytic Model ...
# 39  {'id': 'news38', 'name': 'News Analytic Model ...
# 40  {'id': 'news38', 'name': 'News Analytic Model ...
# 41  {'id': 'news38', 'name': 'News Analytic Model ...
# 42  {'id': 'news38', 'name': 'News Analytic Model ...
# 43  {'id': 'news38', 'name': 'News Analytic Model ...
# 44  {'id': 'news38', 'name': 'News Analytic Model ...
# 45  {'id': 'news38', 'name': 'News Analytic Model ...
# 46  {'id': 'news38', 'name': 'News Analytic Model ...
# 47  {'id': 'news38', 'name': 'News Analytic Model ...
# 48  {'id': 'news38', 'name': 'News Analytic Model ...
# 49  {'id': 'news38', 'name': 'News Analytic Model ...
#
#                           category                          subcategory  \
# 0   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 1   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 2   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 3   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 4   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 5   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 6   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 7   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 8   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 9   {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 10  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 11  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 12  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 13  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 14  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 15  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 16  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 17  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 18  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 19  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 20  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 21  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 22  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 23  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 24  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 25  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 26  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 27  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 28  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 29  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 30  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 31  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 32  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 33  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 34  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 35  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 36  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 37  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 38  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 39  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 40  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 41  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 42  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 43  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 44  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 45  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 46  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 47  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 48  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
# 49  {'id': 'news', 'name': 'News'}  {'id': 'news-news', 'name': 'News'}
#
#    region  delay universe    type  coverage  userCount  alphaCount  \
# 0     USA      1  TOP3000  VECTOR    0.9457          3           8
# 1     USA      1  TOP3000  VECTOR    0.8503          4           5
# 2     USA      1  TOP3000  VECTOR    0.8615          1           1
# 3     USA      1  TOP3000  VECTOR    0.8501          2           6
# 4     USA      1  TOP3000  VECTOR    0.8500          1           2
# 5     USA      1  TOP3000  VECTOR    0.8501          0           0
# 6     USA      1  TOP3000  VECTOR    0.8500          2           3
# 7     USA      1  TOP3000  VECTOR    0.8503          0           0
# 8     USA      1  TOP3000  VECTOR    0.6477          1           1
# 9     USA      1  TOP3000  VECTOR    0.6477          1           1
# 10    USA      1  TOP3000  VECTOR    0.7595          1           1
# 11    USA      1  TOP3000  VECTOR    0.7595          3           3
# 12    USA      1  TOP3000  VECTOR    0.8503          1           1
# 13    USA      1  TOP3000  VECTOR    0.8219          1           1
# 14    USA      1  TOP3000  VECTOR    0.6987          2           2
# 15    USA      1  TOP3000  VECTOR    0.6987          2           5
# 16    USA      1  TOP3000  VECTOR    0.6635          2           2
# 17    USA      1  TOP3000  VECTOR    0.6635          4           6
# 18    USA      1  TOP3000  VECTOR    0.7360          2           2
# 19    USA      1  TOP3000  VECTOR    0.9583          1           1
# 20    USA      1  TOP3000  VECTOR    0.9608          2           2
# 21    USA      1  TOP3000  VECTOR    0.9583          2           7
# 22    USA      1  TOP3000  VECTOR    0.9644          2           2
# 23    USA      1  TOP3000  VECTOR    0.9644          2           2
# 24    USA      1  TOP3000  VECTOR    0.6982          1           1
# 25    USA      1  TOP3000  VECTOR    0.6982          1           1
# 26    USA      1  TOP3000  VECTOR    0.6486          1           1
# 27    USA      1  TOP3000  VECTOR    0.6486          7           7
# 28    USA      1  TOP3000  VECTOR    0.7318          2           2
# 29    USA      1  TOP3000  VECTOR    0.8503          3           4
# 30    USA      1  TOP3000  VECTOR    0.7602          4           4
# 31    USA      1  TOP3000  VECTOR    0.9449          1           2
# 32    USA      1  TOP3000  VECTOR    0.8501          1           6
# 33    USA      1  TOP3000  VECTOR    0.9449          2           4
# 34    USA      1  TOP3000  VECTOR    0.8501          1           1
# 35    USA      1  TOP3000  VECTOR    0.8501          2           2
# 36    USA      1  TOP3000  VECTOR    0.8216          1           1
# 37    USA      1  TOP3000  VECTOR    0.8500          3          19
# 38    USA      1  TOP3000  VECTOR    0.8310          0           0
# 39    USA      1  TOP3000  VECTOR    0.9449          2           4
# 40    USA      1  TOP3000  VECTOR    0.8501          1           1
# 41    USA      1  TOP3000  VECTOR    0.8501          0           0
# 42    USA      1  TOP3000  VECTOR    0.8216          4           6
# 43    USA      1  TOP3000  VECTOR    0.8500          2           2
# 44    USA      1  TOP3000  VECTOR    0.8310          1           2
# 45    USA      1  TOP3000  VECTOR    0.8501          1           1
# 46    USA      1  TOP3000  VECTOR    0.8216          2           2
# 47    USA      1  TOP3000  VECTOR    0.8500          0           0
# 48    USA      1  TOP3000  VECTOR    0.8310          1           1
# 49    USA      1  TOP3000  VECTOR    0.8774          5           5
#
#     pyramidMultiplier themes
# 0                 1.0     []
# 1                 1.0     []
# 2                 1.0     []
# 3                 1.0     []
# 4                 1.0     []
# 5                 1.0     []
# 6                 1.0     []
# 7                 1.0     []
# 8                 1.0     []
# 9                 1.0     []
# 10                1.0     []
# 11                1.0     []
# 12                1.0     []
# 13                1.0     []
# 14                1.0     []
# 15                1.0     []
# 16                1.0     []
# 17                1.0     []
# 18                1.0     []
# 19                1.0     []
# 20                1.0     []
# 21                1.0     []
# 22                1.0     []
# 23                1.0     []
# 24                1.0     []
# 25                1.0     []
# 26                1.0     []
# 27                1.0     []
# 28                1.0     []
# 29                1.0     []
# 30                1.0     []
# 31                1.0     []
# 32                1.0     []
# 33                1.0     []
# 34                1.0     []
# 35                1.0     []
# 36                1.0     []
# 37                1.0     []
# 38                1.0     []
# 39                1.0     []
# 40                1.0     []
# 41                1.0     []
# 42                1.0     []
# 43                1.0     []
# 44                1.0     []
# 45                1.0     []
# 46                1.0     []
# 47                1.0     []
# 48                1.0     []
# 49                1.0     []

# %% [markdown]
# #### Step 3. Create expression list, using selected datafields
# Here is an example: creating expressions that assign weights as per the time series skewness of vector average of the field value

# %%
expression_list = [f'ts_skewness(vec_avg({x}),120)' for x in datafields_df.id.values.tolist()] # create a list of alpha expressions ts_skewness(vec_avg({x}),120) where x is a datafield id

# %% [markdown]
# #### Step 4. Apply generate_alpha function to the expression list
# In generate alpha function you can specify region, universe, decay, delay and other simulation settings

# %%
#when you send multiple alphas for simulation, please make sure all alphas of a single list should have common settings
#alphas with different settings should be sent in a different list, for instance below list has all alphas with same settings

alpha_list = [ace.generate_alpha(x, region= "USA", universe = "TOP3000",) for x in expression_list]

alpha_list[20]
# Out:
# {'type': 'REGULAR',
#  'settings': {'instrumentType': 'EQUITY',
#   'region': 'USA',
#   'universe': 'TOP3000',
#   'delay': 1,
#   'decay': 0,
#   'neutralization': 'INDUSTRY',
#   'truncation': 0.08,
#   'pasteurization': 'ON',
#   'testPeriod': 'P0Y0M0D',
#   'unitHandling': 'VERIFY',
#   'nanHandling': 'OFF',
#   'language': 'FASTEXPR',
#   'visualization': False},
#  'regular': 'ts_skewness(vec_avg(mws38_storyanalytics_score),120)'}

# %% [markdown]
# This is an example - how alpha actually looks like when you send it to the platform.

# %% [markdown]
# ### Simulate alpha list, get simulation result
#
# simulate_alpha_list_multi will do a multi-simulation if list of alphas is greater than 10, which is the case here
#
# the returned object will contain simulation results for all alphas as a list

# %%
#alpha expressions are sliced to first 10 for demonstration purpose

result = ace.simulate_alpha_list_multi(s, alpha_list[:10])
# Out:
# 100%|██████████| 4/4 [02:43<00:00, 40.91s/it]

# %%
#we received a list of 10 simulation results since we sent in alpha_list[:10]
len(result)
# Out:
# 10

# %% [markdown]
# __Accessing the result of the first alpha, let's take a look at all the keys of this dictionary__

# %%
result[1].keys()
# Out:
# dict_keys(['alpha_id', 'simulate_data', 'is_stats', 'pnl', 'stats', 'is_tests', 'train', 'test'])

# %%
#is_stats key will return a dataframe storing IS summary results

result[0]['is_stats']
# Out:
#        pnl  bookSize  longCount  shortCount  turnover  returns  drawdown  \
# 0 -2146626  20000000       1466        1338    0.0487  -0.0215    0.2919
#
#      margin  fitness  sharpe   startDate alpha_id
# 0 -0.000883    -0.18   -0.43  2012-07-15  6e6rX5p

# %%
#prettify_result function can be used from the helpful_functions library to take a look at IS stats of all the simulated alphas

result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  7026382   20000000        1214         1487    0.0845   0.0704    0.6027
# 1  1207449   20000000        1288         1131    0.0574   0.0121    0.0646
# 2   759492   20000000        1426         1378    0.0595   0.0077    0.1485
# 3 -2146626   20000000        1466         1338    0.0487  -0.0215    0.2919
# 4 -2146626   20000000        1466         1338    0.0487  -0.0215    0.2919
# 5 -1764477   20000000        1454         1350    0.0620  -0.0177    0.2241
# 6 -2778545   20000000        1422         1382    0.0484  -0.0278    0.3320
# 7 -2778545   20000000        1422         1382    0.0484  -0.0278    0.3320
# 8 -2004492   20000000        1492         1312    0.0614  -0.0201    0.2639
# 9 -2004492   20000000        1492         1312    0.0614  -0.0201    0.2639
#
#      margin  fitness  sharpe  ... alpha_id  \
# 0  0.001666     0.23    0.30  ...  vv7kwJw
# 1  0.000422     0.12    0.37  ...  X8ZWQbx
# 2  0.000258     0.04    0.16  ...  R1xVjrd
# 3 -0.000883    -0.18   -0.43  ...  6e6rX5p
# 4 -0.000883    -0.18   -0.43  ...  X8ZWmjz
# 5 -0.000570    -0.24   -0.65  ...  MLv1M88
# 6 -0.001151    -0.27   -0.58  ...  dRJOkxK
# 7 -0.001151    -0.27   -0.58  ...  5kKQnwn
# 8 -0.000654    -0.29   -0.73  ...  vv7kwK3
# 9 -0.000654    -0.29   -0.73  ...  NREQx6g
#
#                                           expression concentrated_weight  \
# 0      ts_skewness(vec_avg(mws38_negative_freq),120)                FAIL
# 1     ts_skewness(vec_avg(mws38_negative_score),120)                PASS
# 2             ts_skewness(vec_avg(mws38_action),120)                PASS
# 3  ts_skewness(vec_avg(mws38_headlinetones_sg_ent...                PASS
# 4  ts_skewness(vec_avg(mws38_headlinetones_tc_ent...                PASS
# 5  ts_skewness(vec_avg(mws38_headlinetones_time),...                PASS
# 6  ts_skewness(vec_avg(mws38_headlinetones_entitl...                PASS
# 7        ts_skewness(vec_avg(mws38_entitlement),120)                PASS
# 8  ts_skewness(vec_avg(mws38_headlinetones_sg_tim...                PASS
# 9  ts_skewness(vec_avg(mws38_headlinetones_tc_tim...                PASS
#
#   high_turnover low_2y_sharpe low_fitness low_sharpe low_sub_universe_sharpe  \
# 0          PASS          FAIL        FAIL       FAIL                    FAIL
# 1          PASS          FAIL        FAIL       FAIL                    PASS
# 2          PASS          FAIL        FAIL       FAIL                    PASS
# 3          PASS          FAIL        FAIL       FAIL                    FAIL
# 4          PASS          FAIL        FAIL       FAIL                    FAIL
# 5          PASS          FAIL        FAIL       FAIL                    PASS
# 6          PASS          FAIL        FAIL       FAIL                    FAIL
# 7          PASS          FAIL        FAIL       FAIL                    FAIL
# 8          PASS          FAIL        FAIL       FAIL                    PASS
# 9          PASS          FAIL        FAIL       FAIL                    PASS
#
#   low_turnover matches_pyramid
# 0         PASS            PASS
# 1         PASS            PASS
# 2         PASS            PASS
# 3         PASS            PASS
# 4         PASS            PASS
# 5         PASS            PASS
# 6         PASS            PASS
# 7         PASS            PASS
# 8         PASS            PASS
# 9         PASS            PASS
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Visualise pnl of an alpha

# %%
alpha_pnl = ace.get_alpha_pnl(s, result_st1['alpha_id'][0])
px.line(x = alpha_pnl.index, y = alpha_pnl.Pnl, title=f'<b>alpha_id={hf.make_clickable_alpha_id(alpha_pnl.alpha_id[0])}</b>')\
    .update_layout(xaxis_title="Date", yaxis_title="Pnl", title_x=0.5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13200\488132262.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <div>                            <div id="75668fae-a294-4462-9343-2d6093e2f8e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75668fae-a294-4462-9343-2d6093e2f8e4")) {                    Plotly.newPlot(                        "75668fae-a294-4462-9343-2d6093e2f8e4",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2012-07-16T00:00:00","2012-07-17T00:00:00","2012-07-18T00:00:00","2012-07-19T00:00:00","2012-07-20T00:00:00","2012-07-23T00:00:00","2012-07-24T00:00:00","2012-07-25T00:00:00","2012-07-26T00:00:00","2012-07-27T00:00:00","2012-07-30T00:00:00","2012-07-31T00:00:00","2012-08-01T00:00:00","2012-08-02T00:00:00","2012-08-03T00:00:00","2012-08-06T00:00:00","2012-08-07T00:00:00","2012-08-08T00:00:00","2012-08-09T00:00:00","2012-08-10T00:00:00","2012-08-13T00:00:00","2012-08-14T00:00:00","2012-08-15T00:00:00","2012-08-16T00:00:00","2012-08-17T00:00:00","2012-08-20T00:00:00","2012-08-21T00:00:00","2012-08-22T00:00:00","2012-08-23T00:00:00","2012-08-24T00:00:00","2012-08-27T00:00:00","2012-08-28T00:00:00","2012-08-29T00:00:00","2012-08-30T00:00:00","2012-08-31T00:00:00","2012-09-04T00:00:00","2012-09-05T00:00:00","2012-09-06T00:00:00","2012-09-07T00:00:00","2012-09-10T00:00:00","2012-09-11T00:00:00","2012-09-12T00:00:00","2012-09-13T00:00:00","2012-09-14T00:00:00","2012-09-17T00:00:00","2012-09-18T00:00:00","2012-09-19T00:00:00","2012-09-20T00:00:00","2012-09-21T00:00:00","2012-09-24T00:00:00","2012-09-25T00:00:00","2012-09-26T00:00:00","2012-09-27T00:00:00","2012-09-28T00:00:00","2012-10-01T00:00:00","2012-10-02T00:00:00","2012-10-03T00:00:00","2012-10-04T00:00:00","2012-10-05T00:00:00","2012-10-08T00:00:00","2012-10-09T00:00:00","2012-10-10T00:00:00","2012-10-11T00:00:00","2012-10-12T00:00:00","2012-10-15T00:00:00","2012-10-16T00:00:00","2012-10-17T00:00:00","2012-10-18T00:00:00","2012-10-19T00:00:00","2012-10-22T00:00:00","2012-10-23T00:00:00","2012-10-24T00:00:00","2012-10-25T00:00:00","2012-10-26T00:00:00","2012-10-31T00:00:00","2012-11-01T00:00:00","2012-11-02T00:00:00","2012-11-05T00:00:00","2012-11-06T00:00:00","2012-11-07T00:00:00","2012-11-08T00:00:00","2012-11-09T00:00:00","2012-11-12T00:00:00","2012-11-13T00:00:00","2012-11-14T00:00:00","2012-11-15T00:00:00","2012-11-16T00:00:00","2012-11-19T00:00:00","2012-11-20T00:00:00","2012-11-21T00:00:00","2012-11-23T00:00:00","2012-11-26T00:00:00","2012-11-27T00:00:00","2012-11-28T00:00:00","2012-11-29T00:00:00","2012-11-30T00:00:00","2012-12-03T00:00:00","2012-12-04T00:00:00","2012-12-05T00:00:00","2012-12-06T00:00:00","2012-12-07T00:00:00","2012-12-10T00:00:00","2012-12-11T00:00:00","2012-12-12T00:00:00","2012-12-13T00:00:00","2012-12-14T00:00:00","2012-12-17T00:00:00","2012-12-18T00:00:00","2012-12-19T00:00:00","2012-12-20T00:00:00","2012-12-21T00:00:00","2012-12-24T00:00:00","2012-12-26T00:00:00","2012-12-27T00:00:00","2012-12-28T00:00:00","2012-12-31T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T ...

# %% [markdown]
# ### Select prospect alphas, that are worth improving (in your opinion)
# In this example we are selecting alphas with high fitness, to resimulate it with improved logic

# %%
prospect_alphas = result_st1.loc[lambda x: x.fitness>0.2]['expression'].values
prospect_alphas
# Out:
# array(['ts_skewness(vec_avg(mws38_negative_freq),120)'], dtype=object)

# %% [markdown]
# ### Change the expression - what would you do to improve alpha's results?
# <br>Use your own logic to improve the alphas.</br>
# <br>Here we will apply **group_rank** to overcome poor weight distribution.</br>

# %%
new_expression_list = ['group_rank(' + a + ',sector)' for a in prospect_alphas]
new_expression_list
# Out:
# ['group_rank(ts_skewness(vec_avg(mws38_negative_freq),120),sector)']

# %%
#generating new simulation data for new expressions

new_alpha_list = [ace.generate_alpha(x, region= "USA", universe = "TOP3000",) for x in new_expression_list]

# %% [markdown]
# ### Re-simulation

# %%
new_result = ace.simulate_alpha_list_multi(s, new_alpha_list)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|██████████| 1/1 [01:37<00:00, 97.35s/it]

# %%
result_st2 = hf.prettify_result(new_result, clickable_alpha_id=False)
result_st2
# Out:
#       pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0 -222879   20000000        1342         1358    0.0568  -0.0022    0.1052
#
#      margin  fitness  sharpe  ... alpha_id  \
# 0 -0.000079    -0.01   -0.07  ...  Q9R3emG
#
#                                           expression concentrated_weight  \
# 0  group_rank(ts_skewness(vec_avg(mws38_negative_...                PASS
#
#   high_turnover low_2y_sharpe low_fitness low_sharpe low_sub_universe_sharpe  \
# 0          PASS          FAIL        FAIL       FAIL                    FAIL
#
#   low_turnover matches_pyramid
# 0         PASS            PASS
#
# [1 rows x 21 columns]

# %% [markdown]
# #### Compare alphas stats before and after changes:

# %%
## We will join before and after dataframes by field

result_st1['field'] = result_st1['expression'].apply(lambda st: st[st.find("(vec_avg(")+1:st.find(",")]).copy()
result_st2['field'] = result_st2['expression'].apply(lambda st: st[st.find("(vec_avg(")+1:st.find(",")]).copy()

# %%
#merging results before and after improvement

compare_results = pd.merge(result_st1, result_st2, on='field', suffixes=('_before', '_after'))

# %%
#selecting column list returned by merging the two alpha results

col_list = ['fitness_before', 'fitness_after','sharpe_before', 'sharpe_after', 'alpha_id_before', 'alpha_id_after',
                 'expression_before', 'expression_after']

compare_results[col_list]\
    .style.format({'alpha_id_before': hf.make_clickable_alpha_id, 'alpha_id_after': hf.make_clickable_alpha_id})
# Out:
# <style type="text/css">
# </style>
# <table id="T_51230">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51230_level0_col0" class="col_heading level0 col0" >fitness_before</th>
#       <th id="T_51230_level0_col1" class="col_heading level0 col1" >fitness_after</th>
#       <th id="T_51230_level0_col2" class="col_heading level0 col2" >sharpe_before</th>
#       <th id="T_51230_level0_col3" class="col_heading level0 col3" >sharpe_after</th>
#       <th id="T_51230_level0_col4" class="col_heading level0 col4" >alpha_id_before</th>
#       <th id="T_51230_level0_col5" class="col_heading level0 col5" >alpha_id_after</th>
#       <th id="T_51230_level0_col6" class="col_heading level0 col6" >expression_before</th>
#       <th id="T_51230_level0_col7" class="col_heading level0 col7" >expression_after</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51230_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51230_row0_col0" class="data row0 col0" >0.230000</td>
#       <td id="T_51230_row0_col1" class="data row0 col1" >-0.010000</td>
#       <td id="T_51230_row0_col2" class="data row0 col2" >0.300000</td>
#       <td id="T_51230_row0_col3" class="data row0 col3" >-0.070000</td>
#       <td id="T_51230_row0_col4" class="data row0 col4" ><a href="https://platform.worldquantbrain.com/alpha/vv7kwJw">vv7kwJw</a></td>
#       <td id="T_51230_row0_col5" class="data row0 col5" ><a href="https://platform.worldquantbrain.com/alpha/Q9R3emG">Q9R3emG</a></td>
#       <td id="T_51230_row0_col6" class="data row0 col6" >ts_skewness(vec_avg(mws38_negative_freq),120)</td>
#       <td id="T_51230_row0_col7" class="data row0 col7" >group_rank(ts_skewness(vec_avg(mws38_negative_freq),120),sector)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Check merged alpha performance
#
# run the following code to do a before and after comparison of your merged pool post alpha submission

# %%
performance_comparison = ace.performance_comparison(s, result_st2['alpha_id'][0])

# %% [markdown]
# ### How to submit?
#
# Create a list of submittable alphas - alphas that have no FAIL in is_tests

# %%
#to take a look at the combined result of all new alphas

is_tests_df = hf.concat_is_tests(new_result)
is_tests_df.head()
# Out:
#   alpha_id  limit  multiplier                 name pyramids result   value
# 0  Q9R3emG   1.58         NaN           LOW_SHARPE      NaN   FAIL -0.0700
# 1  Q9R3emG   1.00         NaN          LOW_FITNESS      NaN   FAIL -0.0100
# 2  Q9R3emG   0.01         NaN         LOW_TURNOVER      NaN   PASS  0.0568
# 3  Q9R3emG   0.70         NaN        HIGH_TURNOVER      NaN   PASS  0.0568
# 4  Q9R3emG    NaN         NaN  CONCENTRATED_WEIGHT      NaN   PASS     NaN

# %%
#making a list of failed alphas
failed_alphas = is_tests_df.query('result=="FAIL"')['alpha_id'].unique()

#making a list of passed alphas
passed_alphas = list(set(is_tests_df['alpha_id']).difference(failed_alphas))

print(f'Failed alphas:{failed_alphas}\nPassed alphas:{passed_alphas}')
# Out:
# Failed alphas:['Q9R3emG']
# Passed alphas:[]

# %% [markdown]
# When you got a list of submittable alphas, you can call function submit_alpha()

# %%
#calling submit_alpha on all alphas that have passed the submission tests

submit_result = {alpha_id: submit_alpha(s, alpha_id) for alpha_id in passed_alphas}

# %%
#submit_result will have return values from the submit_result function

submit_result
# Out:
# {}

# %% [markdown]
# ### Library Fuctions.
#
# following are some other functions that you can use for your own analysis
#
# **get_alpha_pnl(s, alpha_id)** - to get the pnl for an alpha
#
# **get_alpha_yearly_stats(s, alpha_id)** - to get yearly statistics for an alpha
#
# **get_self_corr(s, alpha_id)** - to get self correlation results for an alpha
#
# **get_prod_corr(s, alpha_id)** - to get prod correlation results for an alpha
#
# **get_check_submission(s, alpha_id)** - to get check submission result for an alpha
#
# **check_self_corr_test(s, alpha_id)** - to check if alpha passes self correlation test (self_corr<0.7)
#
# **check_prod_corr_test(s, alpha_id)** - to check if alpha passes prod correlation test (prod_corr<0.7)
#
# **perfomance_comparison(s, alpha_id)** - to get the result of performance comparison for an alpha merged performance
